# %%
import daft

# mc - done
# hmm - done
# b-hmm - done
# s-hdp-hmm - done

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

font_size = 14
no_outline = {'ec': 'None'}

pgm = daft.PGM(grid_unit=3, node_unit=1.5, aspect=1, shape=[6,2])

pgm.add_node("z1", r"$z_{1}$", 1, 1, fontsize=font_size)
pgm.add_node("z2", r"$z_{2}$", 2, 1, fontsize=font_size)
pgm.add_node("z3", r"$z_{3}$", 3, 1, fontsize=font_size)
pgm.add_node("z4", r"$\ldots$",4, 1, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("z5", r"$z_{T}$", 5, 1, fontsize=font_size)

# pgm.add_node("x1", r"x", 6, 2, fontsize=font_size, observed=False)
# pgm.add_node("x2", r"x", 0, 0, fontsize=font_size, observed=False)

pgm.add_edge("z1", "z2")
pgm.add_edge("z2", "z3")
pgm.add_edge("z3", "z4")
pgm.add_edge("z4", "z5")


pgm.render()
pgm.savefig('markov-chain.pdf')
pgm.show()

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

font_size = 14
no_outline = {'ec': 'None'}

pgm = daft.PGM(grid_unit=3, node_unit=1.5, aspect=1, shape=[6,3])

pgm.add_node("z1", r"$z_{1}$", 1, 2, fontsize=font_size)
pgm.add_node("z2", r"$z_{2}$", 2, 2, fontsize=font_size)
pgm.add_node("z3", r"$z_{3}$", 3, 2, fontsize=font_size)
pgm.add_node("z4", r"$\ldots$",4, 2, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("z5", r"$z_{T}$", 5, 2, fontsize=font_size)
# pgm.add_node("z", r"$z_{ji}$", 2, 2, fontsize=font_size)
pgm.add_node("y1", r"$y_{1}$", 1, 1, observed=True, fontsize=font_size)
pgm.add_node("y2", r"$y_{2}$", 2, 1, observed=True, fontsize=font_size)
pgm.add_node("y3", r"$y_{3}$", 3, 1, observed=True, fontsize=font_size)
pgm.add_node("y4", r"$\ldots$",4, 1, observed=False, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("y5", r"$y_{T}$", 5, 1, observed=True, fontsize=font_size)

# pgm.add_node("x1", r"x", 6, 3, fontsize=font_size, observed=False)
# pgm.add_node("x2", r"x", 0, 0, fontsize=font_size, observed=False)

pgm.add_edge("z1", "z2")
pgm.add_edge("z2", "z3")
pgm.add_edge("z3", "z4")
pgm.add_edge("z4", "z5")

pgm.add_edge("z1", "y1")
pgm.add_edge("z2", "y2")
pgm.add_edge("z3", "y3")
# pgm.add_edge("z4", "y4")
pgm.add_edge("z5", "y5")

pgm.render()
pgm.savefig('hmm.pdf')
pgm.show()

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt
# FHMM

font_size = 14
no_outline = {'ec': 'None'}

pgm = daft.PGM(grid_unit=3, node_unit=1.5, aspect=1, shape=[6,5])

pgm.add_node("z1", r"$z^{1}_{1}$", 1, 4, fontsize=font_size)
pgm.add_node("z2", r"$z^{1}_{2}$", 2, 4, fontsize=font_size)
pgm.add_node("z3", r"$z^{1}_{3}$", 3, 4, fontsize=font_size)
pgm.add_node("z4", r"$\ldots$",4, 4, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("z5", r"$z^{1}_{T}$", 5, 4, fontsize=font_size)
# pgm.add_node("z", r"$z_{ji}$", 2, 2, fontsize=font_size)
pgm.add_node("y1", r"$y_{1}$", 1, 3, observed=True, fontsize=font_size)
pgm.add_node("y2", r"$y_{2}$", 2, 3, observed=True, fontsize=font_size)
pgm.add_node("y3", r"$y_{3}$", 3, 3, observed=True, fontsize=font_size)
pgm.add_node("y4", r"$\ldots$",4, 3, observed=False, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("y5", r"$y_{T}$", 5, 3, observed=True, fontsize=font_size)

pgm.add_node("z1b", r"$z^{2}_{1}$", 1, 2, fontsize=font_size)
pgm.add_node("z2b", r"$z^{2}_{2}$", 2, 2, fontsize=font_size)
pgm.add_node("z3b", r"$z^{2}_{3}$", 3, 2, fontsize=font_size)
pgm.add_node("z4b", r"$\ldots$",4, 2, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("z5b", r"$z^{2}_{T}$", 5, 2, fontsize=font_size)

pgm.add_node("x1", r"x", 6, 5, fontsize=font_size, observed=False)
pgm.add_node("x2", r"x", 0, 0, fontsize=font_size, observed=False)

pgm.add_edge("z1", "z2")
pgm.add_edge("z2", "z3")
pgm.add_edge("z3", "z4")
pgm.add_edge("z4", "z5")

pgm.add_edge("z1b", "y1")
pgm.add_edge("z2b", "y2")
pgm.add_edge("z3b", "y3")
# pgm.add_edge("z4", "y4")
pgm.add_edge("z5b", "y5")

pgm.add_edge("z1", "y1")
pgm.add_edge("z2", "y2")
pgm.add_edge("z3", "y3")
# pgm.add_edge("z4", "y4")
pgm.add_edge("z5", "y5")

pgm.add_edge("z1b", "z2b")
pgm.add_edge("z2b", "z3b")
pgm.add_edge("z3b", "z4b")
pgm.add_edge("z4b", "z5b")

pgm.render()
pgm.savefig('fhmm.pdf')
pgm.show()

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt

font_size = 14
no_outline = {'ec': 'None'}
pgm = daft.PGM(grid_unit=3, node_unit=1.5, aspect=1, shape=[10,5])

# Hyperparameters
pgm.add_node("alpha_a", r"$\alpha_{a}$", 1, 4, fontsize=font_size, plot_params=no_outline)
pgm.add_node("a", r"$A$", 2, 4, fontsize=font_size)

pgm.add_node("alpha_p", r"$\alpha_{\pi}$", 1, 3, fontsize=font_size, plot_params=no_outline)
pgm.add_node("pie", r"$\pi_j$", 2, 3, fontsize=font_size)


# pgm.add_node("lambda", r"$\lambda$", 3.5, 3, fixed=True, fontsize=font_size)
pgm.add_node("theta", r"$\theta_j$", 2, 2, fontsize=font_size)
pgm.add_node("h", r"$H$", 1, 2, fontsize=font_size, plot_params=no_outline)

pgm.add_node("z1", r"$z_{1}$", 3.5, 2, fontsize=font_size)
pgm.add_node("z2", r"$z_{2}$", 4.5, 2, fontsize=font_size)
pgm.add_node("z3", r"$z_{3}$", 5.5, 2, fontsize=font_size)
pgm.add_node("z4", r"$\ldots$", 6.5, 2, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("z5", r"$z_{T}$", 7.5, 2, fontsize=font_size)

# pgm.add_node("z", r"$z_{ji}$", 2, 2, fontsize=font_size)
pgm.add_node("y1", r"$y_{1}$", 3.5, 1, observed=True, fontsize=font_size)
pgm.add_node("y2", r"$y_{2}$", 4.5, 1, observed=True, fontsize=font_size)
pgm.add_node("y3", r"$y_{3}$", 5.5, 1, observed=True, fontsize=font_size)
pgm.add_node("y4", r"$\ldots$", 6.5, 1, observed=False, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("y5", r"$y_{T}$", 7.5, 1, observed=True, fontsize=font_size)

# pgm.add_node("x1", r"x", 10, 5, fontsize=font_size, observed=False)
# pgm.add_node("x2", r"x", 0, 0, fontsize=font_size, observed=False)

# Base distribution G0
pgm.add_edge("h", "theta")
pgm.add_edge("theta", "y1")
pgm.add_edge("theta", "y2")
pgm.add_edge("theta", "y3")
pgm.add_edge("theta", "y5")

# pgm.add_edge("y3", y_dot)

pgm.add_edge("pie", "z1")
pgm.add_edge("a", "z2")
pgm.add_edge("a", "z3")
pgm.add_edge("a", "z5")
# pgm.add_edge("alpha", "pie")
#
pgm.add_edge("z1", "z2")
pgm.add_edge("z2", "z3")
pgm.add_edge("z3", "z4")
pgm.add_edge("z4", "z5")

pgm.add_edge("z1", "y1")
pgm.add_edge("z2", "y2")
pgm.add_edge("z3", "y3")
# pgm.add_edge("z4", "y4")
pgm.add_edge("z5", "y5")


pgm.add_edge("alpha_a", "a")
pgm.add_edge("alpha_p", "pie")

# Create a custom arrow that goes away from the node

# And a plate.
# pgm.add_plate([1.5, 2.7, 1, 0.7], label=r"$J$", shift=-0.1, fontsize=font_size)
pgm.add_plate([1.5, 1.7, 1, 2.7], label=r"$J$", shift=-0.1, fontsize=font_size)

pgm.render()
pgm.savefig('bhmm.pdf')
pgm.show()

# %%
font_size = 14
no_outline = {'ec': 'None'}
pgm = daft.PGM(grid_unit=3, node_unit=1.5, aspect=1, shape=[10,5])

# Hyperparameters
pgm.add_node("gamma", r"$\gamma$", 1, 4, fontsize=font_size, plot_params=no_outline)
pgm.add_node("beta", r"$\beta$", 2, 4, fontsize=font_size)

pgm.add_node("alpha", r"$\alpha$", 1, 3, fontsize=font_size, plot_params=no_outline)
pgm.add_node("kappa", r"$\kappa$", 1, 3.5, fontsize=font_size, plot_params=no_outline)
pgm.add_node("pie", r"$\pi_j$", 2, 3, fontsize=font_size)


# pgm.add_node("lambda", r"$\lambda$", 3.5, 3, fixed=True, fontsize=font_size)
pgm.add_node("theta", r"$\theta_j$", 2, 2, fontsize=font_size)
pgm.add_node("h", r"$H$", 1, 2, fontsize=font_size, plot_params=no_outline)

pgm.add_node("z1", r"$z_{1}$", 3.5, 2, fontsize=font_size)
pgm.add_node("z2", r"$z_{2}$", 4.5, 2, fontsize=font_size)
pgm.add_node("z3", r"$z_{3}$", 5.5, 2, fontsize=font_size)
pgm.add_node("z4", r"$\ldots$", 6.5, 2, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("z5", r"$z_{T}$", 7.5, 2, fontsize=font_size)

# pgm.add_node("z", r"$z_{ji}$", 2, 2, fontsize=font_size)
pgm.add_node("y1", r"$y_{1}$", 3.5, 1, observed=True, fontsize=font_size)
pgm.add_node("y2", r"$y_{2}$", 4.5, 1, observed=True, fontsize=font_size)
pgm.add_node("y3", r"$y_{3}$", 5.5, 1, observed=True, fontsize=font_size)
pgm.add_node("y4", r"$\ldots$", 6.5, 1, observed=False, fontsize=font_size, plot_params={'ec': 'None'})
pgm.add_node("y5", r"$y_{T}$", 7.5, 1, observed=True, fontsize=font_size)

pgm.add_edge("beta", "pie")

# Base distribution G0
pgm.add_edge("h", "theta")
pgm.add_edge("theta", "y1")
pgm.add_edge("theta", "y2")
pgm.add_edge("theta", "y3")
pgm.add_edge("theta", "y5")

# pgm.add_edge("y3", y_dot)

pgm.add_edge("pie", "z1")
pgm.add_edge("pie", "z2")
pgm.add_edge("pie", "z3")
pgm.add_edge("pie", "z5")
# pgm.add_edge("alpha", "pie")
#
pgm.add_edge("z1", "z2")
pgm.add_edge("z2", "z3")
pgm.add_edge("z3", "z4")
pgm.add_edge("z4", "z5")

pgm.add_edge("z1", "y1")
pgm.add_edge("z2", "y2")
pgm.add_edge("z3", "y3")
# pgm.add_edge("z4", "y4")
pgm.add_edge("z5", "y5")


# pgm.add_edge("theta", "y")
#
pgm.add_edge("gamma", "beta")
pgm.add_edge("alpha", "pie")
pgm.add_edge("kappa", "pie")
# pgm.add_edge("pie", "z")
# pgm.add_edge("z", "y")

# Create a custom arrow that goes away from the node


# Add the arrow and label to the PGM

# And a plate.
pgm.add_plate([1.5, 2.7, 1, 0.7], label=r"$\infty$", shift=-0.1, fontsize=font_size+6)
pgm.add_plate([1.5, 1.7, 1, 0.7], label=r"$\infty$", shift=-0.1, fontsize=font_size+6)

pgm.render()
pgm.show()
