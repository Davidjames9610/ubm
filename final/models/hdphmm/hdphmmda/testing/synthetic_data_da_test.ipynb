# %%
import sys
sys.path.append("/Users/david/Documents/mastersCode/ubm")
print(sys.path)
# Out:
# ['/Users/david/Documents/mastersCode/ubm/final/models/hdphmm/hdphmmda/testing', '/Users/david/.conda/envs/ubm/lib/python310.zip', '/Users/david/.conda/envs/ubm/lib/python3.10', '/Users/david/.conda/envs/ubm/lib/python3.10/lib-dynload', '', '/Users/david/.conda/envs/ubm/lib/python3.10/site-packages', '/Users/david/Documents/mastersCode/ubm']

# %%
import pickle
from importlib import reload
import numpy as np

# %%
# Load state sequence and data from the pickle file
with open('/Users/david/Documents/mastersCode/ubm/final/models/hdphmm/hmm_data_a.pkl', 'rb') as file:
    loaded_data = pickle.load(file)

# Access the loaded data
loaded_ss = loaded_data['state_sequence']
loaded_data = loaded_data['data']

# %%
import final.models.hdphmm.hdphmmda.hdp_hmm_da as hdp_hmm_da
from final.models.hdphmm.hdphmmda.hdp_hmm_da_utils.hdp_hmm_da_consts import *
reload(hdp_hmm_da)
sbp = {
    ALPHA0: 0.2,
    GAMMA0: 0.2,
    KAPPA0: 0.2,
}

sbp[RHO0] = sbp[KAPPA0] / ( sbp[KAPPA0] + sbp[ALPHA0])
temp = 1
hdp_hmm = hdp_hmm_da.InfiniteDirectSamplerHMM(loaded_data, 10, loaded_ss, iterations=50, verbose=True, sbp=sbp, temp=temp)
# Out:
# sbp_prior
# init ari 0.263

# %%
hdp_hmm.fit()
# Out:
# warning self.nk == nk) != True:
# deleting component(s),  [7]
# deleting component(s),  [4]
# iter:  2    ARI:  0.55       ll:  -964.6225027170536     K:  8
# iter:  3    ARI:  0.53       ll:  -966.7103069905144     K:  8
# deleting component(s),  [2]
# iter:  4    ARI:  0.549       ll:  -967.0117534951004     K:  7
# iter:  5    ARI:  0.616       ll:  -970.5341829698322     K:  7
# iter:  6    ARI:  0.733       ll:  -960.674972557871     K:  7
# deleting component(s),  [2]
# iter:  7    ARI:  0.791       ll:  -963.8612729970711     K:  6
# iter:  8    ARI:  0.84       ll:  -961.2418474254122     K:  6
# deleting component(s),  [0]
# iter:  9    ARI:  0.929       ll:  -964.2331588124116     K:  5
# iter:  10    ARI:  0.939       ll:  -964.5543329835012     K:  5
# deleting component(s),  [0]
# iter:  11    ARI:  0.959       ll:  -960.4787990068736     K:  4
# iter:  12    ARI:  0.959       ll:  -957.937240027144     K:  4
# iter:  13    ARI:  0.99       ll:  -960.6578737790543     K:  4
# deleting component(s),  [3]
# iter:  14    ARI:  1.0       ll:  -962.0435289652995     K:  3
# iter:  15    ARI:  1.0       ll:  -961.3453107512373     K:  3
# iter:  16    ARI:  1.0       ll:  -961.6091252925249     K:  3
# iter:  17    ARI:  1.0       ll:  -961.148125321793     K:  3
# iter:  18    ARI:  1.0       ll:  -961.4308190894201     K:  3
# iter:  19    ARI:  1.0       ll:  -960.1317478133707     K:  3
# iter:  20    ARI:  1.0       ll:  -960.1120395437578     K:  3
# iter:  21    ARI:  1.0       ll:  -963.8129999910994     K:  3
# iter:  22    ARI:  1.0       ll:  -963.4561863834449     K:  3
# iter:  23    ARI:  1.0       ll:  -961.1073637938291     K:  3
# iter:  24    ARI:  1.0       ll:  -960.5476151382073     K:  3
# iter:  25    ARI:  1.0       ll:  -964.0845975121689     K:  3
# iter:  26    ARI:  1.0       ll:  -960.8992489087269     K:  3
# iter:  27    ARI:  1.0       ll:  -961.0039218122444     K:  3
# iter:  28    ARI:  1.0       ll:  -961.8632210598485     K:  3
# iter:  29    ARI:  1.0       ll:  -962.0574655417679     K:  3
# iter:  30    ARI:  1.0       ll:  -961.045847834352     K:  3
# iter:  31    ARI:  1.0       ll:  -960.7189788966401     K:  3
# iter:  32    ARI:  1.0       ll:  -966.1935348562138     K:  3
# iter:  33    ARI:  1.0       ll:  -965.4290403621948     K:  3
# iter:  34    ARI:  1.0       ll:  -961.0474076092145     K:  3
# iter:  35    ARI:  1.0       ll:  -960.0499692465263     K:  3
# iter:  36    ARI:  1.0       ll:  -964.3694483593475     K:  3
# iter:  37    ARI:  1.0       ll:  -965.5534211042091     K:  3
# iter:  38    ARI:  1.0       ll:  -960.9695963312059     K:  3
# iter:  39    ARI:  1.0       ll:  -964.2329392610505     K:  3
# iter:  40    ARI:  1.0       ll:  -961.8000608522324     K:  3
# iter:  41    ARI:  1.0       ll:  -960.5337390626138     K:  3
# iter:  42    ARI:  1.0       ll:  -960.2699115449898     K:  3
# iter:  43    ARI:  1.0       ll:  -964.5831475693175     K:  3
# iter:  44    ARI:  1.0       ll:  -961.080388432521     K:  3
# iter:  45    ARI:  1.0       ll:  -960.7500129665162     K:  3
# iter:  46    ARI:  1.0       ll:  -962.5343164376112     K:  3
# iter:  47    ARI:  1.0       ll:  -965.3985250541634     K:  3
# iter:  48    ARI:  1.0       ll:  -961.7223563918762     K:  3
# iter:  49    ARI:  1.0       ll:  -961.7615232293632     K:  3
# completed iterations

# %%
np.log(1e-300)
# Out:
# -690.7755278982137
