# %%
import sys
sys.path.append("/Users/david/Documents/mastersCode/ubm")
print(sys.path)
# Out:
# ['/Users/david/Documents/mastersCode/ubm/final/models/hdphmm/hdphmmda/testing', '/Users/david/.conda/envs/ubm/lib/python310.zip', '/Users/david/.conda/envs/ubm/lib/python3.10', '/Users/david/.conda/envs/ubm/lib/python3.10/lib-dynload', '', '/Users/david/.conda/envs/ubm/lib/python3.10/site-packages', '/Users/david/Documents/mastersCode/ubm']

# %%
import pickle
from importlib import reload

# %%
# Load state sequence and data from the pickle file
with open('hmm_data_a.pkl', 'rb') as file:
    loaded_data = pickle.load(file)

# Access the loaded data
loaded_ss = loaded_data['state_sequence']
loaded_data = loaded_data['data']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load state sequence and data from the pickle file
# ----> 2 with open('hmm_data_a.pkl', 'rb') as file:
#       3     loaded_data = pickle.load(file)
#       5 # Access the loaded data
#
# File ~/.conda/envs/ubm/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hmm_data_a.pkl'

# %%
import final.models.hdphmm.hdphmmda.hdp_hmm_da as hdp_hmm_da
from final.models.hdphmm.hdphmmda.hdp_hmm_da_utils.hdp_hmm_da_consts import *
reload(hdp_hmm_da)
sbp = {
    ALPHA0: 10,
    GAMMA0: 2,
    KAPPA0: 0.5,
}

sbp[RHO0] = sbp[KAPPA0] / ( sbp[KAPPA0] + sbp[ALPHA0])
temp = 1
hdp_hmm = hdp_hmm_da.InfiniteDirectSamplerHMM(loaded_data, 4, loaded_ss, iterations=20, verbose=True, sbp=sbp, temp=temp)
# Out:
# sbp_prior
# init ari 0.6

# %%
hdp_hmm.fit()
# Out:
# new state
# new state
# deleting component(s),  [4]
# iter:  2    ARI:  0.796       ll:  -973.6935471989177     K:  5
# iter:  3    ARI:  0.875       ll:  -968.0403210905182     K:  5
# deleting component(s),  [4]
# iter:  4    ARI:  0.94       ll:  -969.1168215630104     K:  4
# new state
# iter:  5    ARI:  0.93       ll:  -967.1822444194152     K:  5
# new state
# iter:  6    ARI:  0.944       ll:  -969.2133226941645     K:  6
# new state
# deleting component(s),  [4]
# deleting component(s),  [4]
# iter:  7    ARI:  0.959       ll:  -967.2707083799525     K:  5
# iter:  8    ARI:  0.969       ll:  -970.9267863401241     K:  5
# deleting component(s),  [4]
# iter:  9    ARI:  0.99       ll:  -967.1380339652954     K:  4
# iter:  10    ARI:  0.979       ll:  -972.0333293735101     K:  4
# deleting component(s),  [0]
# iter:  11    ARI:  1.0       ll:  -970.4488572079886     K:  3
# iter:  12    ARI:  1.0       ll:  -970.6183199400394     K:  3
# iter:  13    ARI:  1.0       ll:  -971.4201669012399     K:  3
# iter:  14    ARI:  1.0       ll:  -967.3561521945051     K:  3
# iter:  15    ARI:  1.0       ll:  -970.9811200671109     K:  3
# iter:  16    ARI:  1.0       ll:  -967.5883141397697     K:  3
# iter:  17    ARI:  1.0       ll:  -975.2619664229735     K:  3
# iter:  18    ARI:  1.0       ll:  -970.4373038889314     K:  3
# iter:  19    ARI:  1.0       ll:  -971.217260715252     K:  3
# completed iterations
