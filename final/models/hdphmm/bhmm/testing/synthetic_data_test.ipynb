# %%
import sys
sys.path.append("/Users/david/Documents/mastersCode/ubm")
print(sys.path)
# Out:
# ['/Applications/PyCharm.app/Contents/plugins/python/helpers-pro/jupyter_debug', '/Applications/PyCharm.app/Contents/plugins/python/helpers/pydev', '/Users/david/Documents/mastersCode/ubm/final/models/hdphmm/bhmm/testing', '/Users/david/.conda/envs/ubm/lib/python310.zip', '/Users/david/.conda/envs/ubm/lib/python3.10', '/Users/david/.conda/envs/ubm/lib/python3.10/lib-dynload', '', '/Users/david/.conda/envs/ubm/lib/python3.10/site-packages', '/Users/david/Documents/mastersCode/ubm', '/Users/david/Documents/mastersCode/ubm']

# %%
import pickle
from importlib import reload
import numpy as np

# %%
# Load state sequence and data from the pickle file
with open('/Users/david/Documents/mastersCode/ubm/final/models/hdphmm/hmm_data_a.pkl', 'rb') as file:
    loaded_data = pickle.load(file)

# Access the loaded data
loaded_ss = loaded_data['state_sequence']
loaded_data = loaded_data['data']

# %%
import final.models.hdphmm.bhmm.bhmm as bhmm
reload(bhmm)
bhmm = bhmm.BayesianHMM(loaded_data, loaded_ss, 20, iterations=100)
import final.models.hdphmm.helpers.plot_hmm as plot_hmm
reload(plot_hmm)
plot_hmm.plot_hmm_data(loaded_data, bhmm.Z, bhmm.K, bhmm.mu, bhmm.sigma, feature_a=0, feature_b=1)
# Out:
# init ari 0.168

# %%
bhmm.fit()
# Out:
# starting gibbs sampling
# more than one zero component
# completed gibbs sampling

# %%
import matplotlib.pyplot as plt

plt.plot(range(0,len(bhmm.ARI)), bhmm.ARI, marker="None")
plt.xlabel('iteration')
plt.ylabel('ARI')
#plt.savefig("./image/ari.png")
plt.show()
plt.close()

# %%
plot_hmm.plot_hmm_data(loaded_data, bhmm.Z, bhmm.K, bhmm.mu, bhmm.sigma, feature_a=0, feature_b=1)
